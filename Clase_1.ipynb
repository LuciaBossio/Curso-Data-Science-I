# %% [markdown]
# <a href="https://colab.research.google.com/github/LuciaBossio/Curso-Data-Science-I/blob/main/Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es el ejemplo de la primera clase

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y=[5,10,15,20,30,25,31,30,20]

# %%
    data_dict={
    "Conocimientos previos":x,
    "Frecuencia": y
}

# %%
df=pd.DataFrame(data_dict)

# %%
display(df)
# Out:
#   Conocimientos previos  Frecuencia
# 0                   EDA           5
# 1        Data Wrangling          10
# 2         Mineria datos          15
# 3        Limpieza Datos          20
# 4                   SQL          30
# 5      Est. Inferencial          25
# 6                    ML          31
# 7                    DL          30
# 8                    IA          20

# %%
sns.barplot(df, x="Conocimientos previos", y="Frecuencia")
plt.figure(figsize=(16, 9))
plt.show()

# %%
plt.figure(figsize=(16, 9))
sns.set_style("darkgrid")
ax = sns.barplot(x="Conocimientos previos", y='Frecuencia', data=df)
plt.title('Importancia de Habilidades en Data Science', fontsize=16)
plt.xlabel('Habilidad', fontsize=12)
plt.ylabel('Nivel de Importancia', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
